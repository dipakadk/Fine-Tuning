# %%
# %%capture
# 1. Ensure torch is installed BEFORE importing it
# !uv add torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

import torch

# 2. Get GPU capability
major_version, minor_version = torch.cuda.get_device_capability()

# 3. Install Unsloth (latest from GitHub)
# !uv add "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# 4. Install other dependencies depending on GPU type
if major_version >= 8:
    # Ampere / Hopper GPUs (RTX 30xx, 40xx, A100, H100, etc.)
    # !uv add --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # Older GPUs (T4, V100, RTX 20xx)
    # !uv add --no-deps xformers trl peft accelerate bitsandbytes

pass
